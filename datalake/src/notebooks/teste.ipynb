# %%
import os 
import sys

import requests

response = requests.get(url="https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/Moedas", params={"$format": "json"})
data = response.json()

# %%
print(data)
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata$metadata#Moedas', 'value': [{'simbolo': 'AUD', 'nomeFormatado': 'Dólar australiano', 'tipoMoeda': 'B'}, {'simbolo': 'CAD', 'nomeFormatado': 'Dólar canadense', 'tipoMoeda': 'A'}, {'simbolo': 'CHF', 'nomeFormatado': 'Franco suíço', 'tipoMoeda': 'A'}, {'simbolo': 'DKK', 'nomeFormatado': 'Coroa dinamarquesa', 'tipoMoeda': 'A'}, {'simbolo': 'EUR', 'nomeFormatado': 'Euro', 'tipoMoeda': 'B'}, {'simbolo': 'GBP', 'nomeFormatado': 'Libra Esterlina', 'tipoMoeda': 'B'}, {'simbolo': 'JPY', 'nomeFormatado': 'Iene', 'tipoMoeda': 'A'}, {'simbolo': 'NOK', 'nomeFormatado': 'Coroa norueguesa', 'tipoMoeda': 'A'}, {'simbolo': 'SEK', 'nomeFormatado': 'Coroa sueca', 'tipoMoeda': 'A'}, {'simbolo': 'USD', 'nomeFormatado': 'Dólar dos Estados Unidos', 'tipoMoeda': 'A'}]}

# %%
data["value"]
# Out:
# [{'simbolo': 'AUD', 'nomeFormatado': 'Dólar australiano', 'tipoMoeda': 'B'},
#  {'simbolo': 'CAD', 'nomeFormatado': 'Dólar canadense', 'tipoMoeda': 'A'},
#  {'simbolo': 'CHF', 'nomeFormatado': 'Franco suíço', 'tipoMoeda': 'A'},
#  {'simbolo': 'DKK', 'nomeFormatado': 'Coroa dinamarquesa', 'tipoMoeda': 'A'},
#  {'simbolo': 'EUR', 'nomeFormatado': 'Euro', 'tipoMoeda': 'B'},
#  {'simbolo': 'GBP', 'nomeFormatado': 'Libra Esterlina', 'tipoMoeda': 'B'},
#  {'simbolo': 'JPY', 'nomeFormatado': 'Iene', 'tipoMoeda': 'A'},
#  {'simbolo': 'NOK', 'nomeFormatado': 'Coroa norueguesa', 'tipoMoeda': 'A'},
#  {'simbolo': 'SEK', 'nomeFormatado': 'Coroa sueca', 'tipoMoeda': 'A'},
#  {'simbolo': 'USD',
#   'nomeFormatado': 'Dólar dos Estados Unidos',
#   'tipoMoeda': 'A'}]

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder.appName("teste").getOrCreate()
)

spark
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 26/03/16 09:25:12 WARN Utils: Your hostname, PcArthur resolves to a loopback address: 127.0.1.1; using 172.30.206.224 instead (on interface eth0)
# 26/03/16 09:25:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/16 09:25:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.30.206.224:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>teste</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.parquet('/home/arthur/Arthur/Projetos/financial_pipeline/datalake/lakehouse/raw/raw_coins/data/dt_reference=2026-03-13')

# %%
df.show()
# Out:
# +------+--------------+-------------+-------------+------------+--------------------+-----------+------------+
# |symbol|paridadeCompra|paridadeVenda|cotacaoCompra|cotacaoVenda|     dataHoraCotacao|tipoBoletim|dt_reference|
# +------+--------------+-------------+-------------+------------+--------------------+-----------+------------+
# |   AUD|        0.7058|       0.7059|        3.699|         3.7|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   CAD|        1.3701|       1.3702|       3.8249|      3.8256|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   CHF|        0.7868|        0.787|       6.6593|      6.6618|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   DKK|        6.5089|       6.5093|       0.8051|      0.8053|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   EUR|         1.148|       1.1481|       6.0166|      6.0178|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   GBP|        1.3272|       1.3276|       6.9557|      6.9586|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   JPY|        159.31|       159.32|       0.0329|      0.0329|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   NOK|        9.7077|       9.7109|       0.5397|      0.5399|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   SEK|        9.3546|       9.3566|       0.5601|      0.5603|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# |   USD|           1.0|          1.0|       5.2409|      5.2415|2026-03-13 10:09:...|   Abertura|  2026-03-15|
# +------+--------------+-------------+-------------+------------+--------------------+-----------+------------+
